# %%
import pandas as pd

# %%
data = pd.read_csv('tourist_numbers_Turkey.csv')
data.head()
# Out:
#          Date     ALMANYA   ARNAVUTLUK   AVUSTURYA    BELCIKA   BOSNAHERSEK  \
# 0  2008-01-01  17723300.0     281100.0   2020700.0  1238900.0      254600.0
# 1  2008-02-01  14366600.0     260400.0   1629500.0  1130900.0      234200.0
# 2  2008-03-01  24979700.0     362600.0   2355800.0  2109700.0      295200.0
# 3  2008-04-01  24253100.0     321900.0   2266800.0  3077200.0      353900.0
# 4  2008-05-01  39972400.0     415600.0   3226500.0  5048300.0      470900.0
#
#     BULGARISTAN   CEKCUMHURIYETI   DANIMARKA   ESTONYA  ...   TAYLAND  \
# 0     9904800.0         182400.0    561300.0   42600.0  ...   56300.0
# 1     8270700.0         206400.0    546400.0   51500.0  ...   51600.0
# 2    10287700.0         252400.0   1128800.0   69500.0  ...  100300.0
# 3    11062700.0         419800.0   1087800.0  109800.0  ...  108100.0
# 4    14864200.0         928600.0   2600800.0  450800.0  ...  100500.0
#
#       URDUN    YEMEN     DASYA     ASYATOP   AVUSTRALYA   YENIZELLANDA  \
# ...

# %%
# İlk birkaç satırı görüntüleme
print(data.head())

# Veri tiplerini kontrol etme
print(data.dtypes)
# Out:
#          Date     ALMANYA   ARNAVUTLUK   AVUSTURYA    BELCIKA   BOSNAHERSEK  \
# 0  2008-01-01  17723300.0     281100.0   2020700.0  1238900.0      254600.0
# 1  2008-02-01  14366600.0     260400.0   1629500.0  1130900.0      234200.0
# 2  2008-03-01  24979700.0     362600.0   2355800.0  2109700.0      295200.0
# 3  2008-04-01  24253100.0     321900.0   2266800.0  3077200.0      353900.0
# 4  2008-05-01  39972400.0     415600.0   3226500.0  5048300.0      470900.0
#
#     BULGARISTAN   CEKCUMHURIYETI   DANIMARKA   ESTONYA  ...   TAYLAND  \
# 0     9904800.0         182400.0    561300.0   42600.0  ...   56300.0
# 1     8270700.0         206400.0    546400.0   51500.0  ...   51600.0
# 2    10287700.0         252400.0   1128800.0   69500.0  ...  100300.0
# 3    11062700.0         419800.0   1087800.0  109800.0  ...  108100.0
# 4    14864200.0         928600.0   2600800.0  450800.0  ...  100500.0
#
#       URDUN    YEMEN     DASYA     ASYATOP   AVUSTRALYA   YENIZELLANDA  \
# ...

# %%
# Sayısal olmayan verileri kontrol etme
non_numeric = data.select_dtypes(exclude='number')
print(non_numeric)
# Out:
#            Date
# 0    2008-01-01
# 1    2008-02-01
# 2    2008-03-01
# 3    2008-04-01
# 4    2008-05-01
# ..          ...
# 160  2021-05-01
# 161  2021-06-01
# 162  2021-07-01
# 163  2021-08-01
# 164  2021-09-01
#
# [165 rows x 1 columns]

# %%
data.head()
# Out:
#          Date     ALMANYA   ARNAVUTLUK   AVUSTURYA    BELCIKA   BOSNAHERSEK  \
# 0  2008-01-01  17723300.0     281100.0   2020700.0  1238900.0      254600.0
# 1  2008-02-01  14366600.0     260400.0   1629500.0  1130900.0      234200.0
# 2  2008-03-01  24979700.0     362600.0   2355800.0  2109700.0      295200.0
# 3  2008-04-01  24253100.0     321900.0   2266800.0  3077200.0      353900.0
# 4  2008-05-01  39972400.0     415600.0   3226500.0  5048300.0      470900.0
#
#     BULGARISTAN   CEKCUMHURIYETI   DANIMARKA   ESTONYA  ...   TAYLAND  \
# 0     9904800.0         182400.0    561300.0   42600.0  ...   56300.0
# 1     8270700.0         206400.0    546400.0   51500.0  ...   51600.0
# 2    10287700.0         252400.0   1128800.0   69500.0  ...  100300.0
# 3    11062700.0         419800.0   1087800.0  109800.0  ...  108100.0
# 4    14864200.0         928600.0   2600800.0  450800.0  ...  100500.0
#
#       URDUN    YEMEN     DASYA     ASYATOP   AVUSTRALYA   YENIZELLANDA  \
# ...

# %%
# Temel istatistikleri hesaplama
stats = data.describe()
print(stats)
# Out:
#             ALMANYA    ARNAVUTLUK     AVUSTURYA       BELCIKA   BOSNAHERSEK  \
# count  1.650000e+02  1.650000e+02  1.650000e+02  1.650000e+02  1.650000e+02
# mean   3.595753e+07  6.495339e+05  3.498824e+06  4.344815e+06  6.686321e+05
# std    2.347812e+07  3.809939e+05  2.929719e+06  3.721033e+06  4.507163e+05
# min    1.740000e+05  5.340000e+04  1.150000e+04  1.260000e+04  4.770000e+04
# 25%    1.481080e+07  3.823000e+05  1.571900e+06  1.358800e+06  3.810000e+05
# 50%    3.277280e+07  5.233000e+05  2.355800e+06  3.181300e+06  5.396000e+05
# 75%    5.198490e+07  8.528000e+05  4.325100e+06  5.441500e+06  8.710000e+05
# max    9.459020e+07  2.055600e+06  1.452050e+07  1.584200e+07  2.838500e+06
#
#         BULGARISTAN   CEKCUMHURIYETI     DANIMARKA       ESTONYA  \
# count  1.650000e+02     1.650000e+02  1.650000e+02  1.650000e+02
# mean   1.412762e+07     1.479748e+06  2.577336e+06  3.646770e+05
# std    5.119292e+06     1.614864e+06  2.241254e+06  3.133718e+05
# ...

# %%
# Sütun adlarını kontrol et
print(data.columns)
# Out:
# Index(['Date', ' ALMANYA', ' ARNAVUTLUK', ' AVUSTURYA', ' BELCIKA',
#        ' BOSNAHERSEK', ' BULGARISTAN', ' CEKCUMHURIYETI', ' DANIMARKA',
#        ' ESTONYA',
#        ...
#        ' TAYLAND', ' URDUN', ' YEMEN', ' DASYA', ' ASYATOP', ' AVUSTRALYA',
#        ' YENIZELLANDA', ' OKYANUSYA', ' MILLIYESIZ', ' GTOPLAM'],
#       dtype='object', length=103)

# %%
data.iloc[:,1:]=((data.iloc[:,1:])/100).astype('int')

# %%
data.head(10)
# Out:
#          Date   ALMANYA   ARNAVUTLUK   AVUSTURYA   BELCIKA   BOSNAHERSEK  \
# 0  2008-01-01  177233.0       2811.0     20207.0   12389.0        2546.0
# 1  2008-02-01  143666.0       2604.0     16295.0   11309.0        2342.0
# 2  2008-03-01  249797.0       3626.0     23558.0   21097.0        2952.0
# 3  2008-04-01  242531.0       3219.0     22668.0   30772.0        3539.0
# 4  2008-05-01  399724.0       4156.0     32265.0   50483.0        4709.0
# 5  2008-06-01  364145.0       4862.0     44762.0   54415.0        6093.0
# 6  2008-07-01  519849.0       9718.0     69174.0  102714.0        8854.0
# 7  2008-08-01  728774.0      12534.0    145205.0  130769.0        9554.0
# 8  2008-09-01  536884.0       8984.0     49996.0   79138.0        5396.0
# 9  2008-10-01  601367.0       3890.0     41668.0   50641.0        5870.0
#
#     BULGARISTAN   CEKCUMHURIYETI   DANIMARKA   ESTONYA  ...   TAYLAND  \
# 0       99048.0           1824.0      5613.0     426.0  ...     563.0
# ...

# %%
# Doğru sütun adıyla grafik oluşturma
plt.figure(figsize=(12, 6))
sns.lineplot(data=data, x='Date', y='Almanya', label='Almanya')
plt.title('Almanya Verisinin Zaman İçindeki Trendi')
plt.xlabel('Tarih')
plt.ylabel('Değer')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Doğru sütun adıyla grafik oluşturma
#       2 plt.figure(figsize=(12, 6))
# ----> 3 sns.lineplot(data=data, x='Date', y='Almanya', label='Almanya')
#       4 plt.title('Almanya Verisinin Zaman İçindeki Trendi')
#       5 plt.xlabel('Tarih')
#
# File c:\Users\Taner\anaconda3\lib\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
# ...

# %%
data.describe()
# Out:
#                                 Date        ALMANYA    ARNAVUTLUK  \
# count                            165     165.000000    165.000000
# mean   2014-10-31 13:49:05.454545408  359575.284848   6495.339394
# min              2008-01-01 00:00:00    1740.000000    534.000000
# 25%              2011-06-01 00:00:00  148108.000000   3823.000000
# 50%              2014-11-01 00:00:00  327728.000000   5233.000000
# 75%              2018-04-01 00:00:00  519849.000000   8528.000000
# max              2021-09-01 00:00:00  945902.000000  20556.000000
# std                              NaN  234781.205792   3809.938949
#
#            AVUSTURYA        BELCIKA   BOSNAHERSEK    BULGARISTAN  \
# count     165.000000     165.000000    165.000000     165.000000
# mean    34988.242424   43448.145455   6686.321212  141276.169697
# min       115.000000     126.000000    477.000000    6562.000000
# 25%     15719.000000   13588.000000   3810.000000  109059.000000
# ...

# %% [markdown]
# Data Query and Visualization

# %%
from matplotlib.pyplot import figure
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
c_final=continents.sum().nlargest(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 continents = data[['date',
#       2       'ohter europe',
#       3       'europen',
#       4       'sum of cis',
#       5        'other america',
#       6        'america',
#       7       'other africa',
#       8        'africa' ,
#       9        'other asia' ,
#      10        'asia',]]
#      11 continents
#
# File c:\Users\Taner\anaconda3\lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...
