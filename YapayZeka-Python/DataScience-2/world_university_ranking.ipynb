# %%
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import warnings
import os

warnings.filterwarnings("ignore")

# Print available styles
print("Available styles:", plt.style.available)

# Use a default valid style
plt.style.use('ggplot')  # Change to a valid style name

# Print out the paths of files in the 'input' directory
for dirname, _, filenames in os.walk('input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Available styles: ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']
# input\combats.csv
# input\cwurData.csv
# input\educational_attainment_supplementary_data.csv
# input\education_expenditure_supplementary_data.csv
# input\Iris.csv
# input\kl.csv
# input\pokemon.csv
# input\school_and_country_table.csv
# input\shanghaiData.csv
# input\tests.csv
# input\timesData.csv

# %%
cwurData = pd.read_csv('input/cwurData.csv')
print(cwurData.columns)
cwurData.head()
# Out:
# Index(['world_rank', 'institution', 'country', 'national_rank',
#        'quality_of_education', 'alumni_employment', 'quality_of_faculty',
#        'publications', 'influence', 'citations', 'broad_impact', 'patents',
#        'score', 'year'],
#       dtype='object')
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# 0             1          1          1           NaN        5  100.00  2012
# 1            12          4          4           NaN        1   91.67  2012
# 2             4          2          2           NaN       15   89.50  2012
# 3            16         16         11           NaN       50   86.17  2012
# 4            37         22         22           NaN       18   85.21  2012

# %%
shanghaiData = pd.read_csv('input/shanghaiData.csv')
print(shanghaiData.columns)
shanghaiData.head()
# Out:
# Index(['world_rank', 'university_name', 'national_rank', 'total_score',
#        'alumni', 'award', 'hici', 'ns', 'pub', 'pcp', 'year'],
#       dtype='object')
#   world_rank                              university_name national_rank  \
# 0          1                           Harvard University             1
# 1          2                      University of Cambridge             1
# 2          3                          Stanford University             2
# 3          4           University of California, Berkeley             3
# 4          5  Massachusetts Institute of Technology (MIT)             4
#
#    total_score  alumni  award   hici     ns    pub   pcp  year
# 0        100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1         73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 2         73.4    41.1   72.2   88.5   70.9   72.3  65.0  2005
# 3         72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4         70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005

# %%
timesData = pd.read_csv('input/timesData.csv')
print(timesData.columns)
timesData.head()
# Out:
# Index(['world_rank', 'university_name', 'country', 'teaching', 'international',
#        'research', 'citations', 'income', 'total_score', 'num_students',
#        'student_staff_ratio', 'international_students', 'female_male_ratio',
#        'year'],
#       dtype='object')
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching international  research  citations income total_score  \
# 0      99.7          72.4      98.7       98.8   34.5        96.1
# 1      97.7          54.6      98.0       99.9   83.7        96.0
# 2      97.8          82.3      91.4       99.9   87.5        95.6
# 3      98.3          29.5      98.1       99.2   64.3        94.3
# 4      90.9          70.3      95.4       99.9      -        94.2
#
#   num_students  student_staff_ratio international_students female_male_ratio  \
# 0       20,152                  8.9                    25%               NaN
# 1        2,243                  6.9                    27%           33 : 67
# 2       11,074                  9.0                    33%           37 : 63
# 3       15,596                  7.8                    22%           42 : 58
# 4        7,929                  8.4                    27%           45 : 55
#
#    year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %% [markdown]
# Correlation Map

# %%
# Ensure that the data contains numeric columns for correlation calculation
numeric_data = cwurData.select_dtypes(include='number')

# Plot the heatmap
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(numeric_data.corr(), annot=True, linewidths=.5, fmt='.1f', ax=ax)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# Ensure that the data contains numeric columns for correlation calculation
numeric_data = shanghaiData.select_dtypes(include='number')

# Plot the heatmap
f, ax = plt.subplots(figsize=(11, 11))
sns.heatmap(numeric_data.corr(), annot=True, linewidths=.5, fmt='.1f', ax=ax)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
numeric_data = timesData.select_dtypes(include='number')

# Create the heatmap
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(numeric_data.corr(), annot=True, linewidths=.5, fmt='.1f', ax=ax)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# MATPLOTLIB

# %%
# Line Plot
timesData.teaching.plot(kind = 'line', color = 'g',label = 'Teaching',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
timesData.research.plot(color = 'r',label = 'Research',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     
plt.xlabel('x axis')              
plt.ylabel('y axis')
plt.title('Line Plot')          
plt.show()

# %%
# Scatter Plot 
timesData.plot(kind='scatter', x='teaching', y='research',alpha = 0.5,color = 'red')
plt.xlabel('teaching')            
plt.ylabel('research')
plt.title('Scatter Plot')           
plt.show()

# %%
# Histogram
timesData.research.plot(kind = 'hist',bins = 50,figsize = (12,12))
plt.show()

# %%
timesData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2603 entries, 0 to 2602
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   world_rank              2603 non-null   object
#  1   university_name         2603 non-null   object
#  2   country                 2603 non-null   object
#  3   teaching                2603 non-null   float64
#  4   international           2603 non-null   object
#  5   research                2603 non-null   float64
#  6   citations               2603 non-null   float64
#  7   income                  2603 non-null   object
#  8   total_score             2603 non-null   object
#  9   num_students            2544 non-null   object
#  10  student_staff_ratio     2544 non-null   float64
#  11  international_students  2536 non-null   object
#  12  female_male_ratio       2370 non-null   object
#  13  year                    2603 non-null   int64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 284.8+ KB

# %% [markdown]
# Univariate Variable Analysis

# %% [markdown]
# Categorical Variable

# %%
def bar_plot(dataset, variable):
    """
        input: dataset ex:timesData, variable example: "country" or "university_name"
        output: bar plot & value count
    """
    var = dataset[variable]
    varValue = var.value_counts()
    
    # visualize
    plt.figure(figsize = (9,3))
    plt.bar(varValue.index, varValue)
    plt.xticks(varValue.index, varValue.index.values)
    plt.ylabel("Frequency")
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
category1 = ["country", "international", "university_name", "world_rank"]
for c in category1:
    bar_plot(timesData,c)
# Out:
# country:
#  country
# United States of America     659
# United Kingdom               300
# Germany                      152
# Australia                    117
# Canada                       108
#                             ...
# Unted Kingdom                  1
# Cyprus                         1
# Unisted States of America      1
# Luxembourg                     1
# Lithuania                      1
# Name: count, Length: 72, dtype: int64
# international:
#  international
# 29.6    10
# 20.7    10
# 46.8     9
# 34.3     9
# -        9
#         ..
# 40.7     1
# 68.8     1
# 22.8     1
# 38.9     1
# 14.9     1
# Name: count, Length: 804, dtype: int64
# university_name:
#  university_name
# Harvard University                               6
# Lancaster University                             6
# University of Alberta                            6
# University of Glasgow                            6
# Stockholm University                             6
#                                                 ..
# Indian Institute of Technology Guwahati          1
# Huazhong University of Science and Technology    1
# University of Haifa                              1
# University of Granada                            1
# Yokohama National University                     1
# Name: count, Length: 818, dtype: int64
# world_rank:
#  world_rank
# 301-350    248
# 601-800    200
# 351-400    198
# 276-300    104
# 201-225    103
#           ...
# =110         2
# =123         2
# =125         2
# =60          2
# 179          1
# Name: count, Length: 250, dtype: int64

# %% [markdown]
# Numerical Variable

# %%
def plot_hist(dataset,variable):
    plt.figure(figsize = (9,3))
    plt.hist(dataset[variable], bins = 50)
    plt.xlabel(variable)
    plt.ylabel("Frequency")
    plt.title("{} distribution with hist".format(variable))
    plt.show()

# %%
numericVariable = ["teaching", "research", "citations", "student_staff_ratio"]
for n in numericVariable:
    plot_hist(timesData,n)

# %% [markdown]
# Filtering

# %%
# 1 - Filtering Pandas data frame
x = shanghaiData['national_rank']=="1"
shanghaiData[x]
# Out:
#      world_rank                               university_name national_rank  \
# 0             1                            Harvard University             1
# 1             2                       University of Cambridge             1
# 19           20                       The University of Tokyo             1
# 23           24                         University of Toronto             1
# 26           27  Swiss Federal Institute of Technology Zurich             1
# ...         ...                                           ...           ...
# 4766    301-400                           University of Chile             1
# 4773    301-400                          University of Malaya             1
# 4805    401-500                              Cairo University             1
# 4820    401-500                           Istanbul University             1
# 4871    401-500                       University of Ljubljana             1
#
#       total_score  alumni  award   hici     ns    pub   pcp  year
# 0           100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1            73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 19           46.7    36.0   14.4   38.5   52.1   86.5  34.7  2005
# 23           43.1    28.1   19.7   39.3   38.9   76.7  41.9  2005
# 26           41.7    40.2   37.0   35.1   41.1   43.4  52.4  2005
# ...           ...     ...    ...    ...    ...    ...   ...   ...
# 4766          NaN     7.3    0.0    0.0   11.1   33.0  17.1  2015
# 4773          NaN     0.0    0.0    5.0    0.0   43.9  21.6  2015
# 4805          NaN    19.2    0.0    0.0    3.9   31.0  16.5  2015
# 4820          NaN    13.6    0.0    0.0    3.4   34.1  17.2  2015
# 4871          NaN     0.0    0.0    0.0    7.7   35.1  14.2  2015
#
# [343 rows x 11 columns]

# %%
# 1 - Filtering Pandas data frame
x = cwurData['citations']<5
cwurData[x]
# Out:
#       world_rank                            institution country  \
# 0              1                     Harvard University     USA
# 1              2  Massachusetts Institute of Technology     USA
# 2              3                    Stanford University     USA
# 9             10     University of California, Berkeley     USA
# 100            1                     Harvard University     USA
# 101            2                    Stanford University     USA
# 103            4  Massachusetts Institute of Technology     USA
# 106            7     University of California, Berkeley     USA
# 200            1                     Harvard University     USA
# 201            2                    Stanford University     USA
# 202            3  Massachusetts Institute of Technology     USA
# 206            7     University of California, Berkeley     USA
# 1200           1                     Harvard University     USA
# 1201           2                    Stanford University     USA
# 1202           3  Massachusetts Institute of Technology     USA
# 1206           7     University of California, Berkeley     USA
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                     7                  9
# 1                 2                     9                 17
# 2                 3                    17                 11
# 9                 8                    16                 52
# 100               1                     1                  1
# 101               2                    11                  2
# 103               3                     2                 16
# 106               5                     6                 28
# 200               1                     1                  1
# 201               2                    11                  2
# 202               3                     3                 11
# 206               5                     4                 22
# 1200              1                     1                  1
# 1201              2                     9                  2
# 1202              3                     3                 11
# 1206              5                     5                 21
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                      1             1          1          1           NaN
# 1                      3            12          4          4           NaN
# 2                      5             4          2          2           NaN
# 9                      6             6          5          3           NaN
# 100                    1             1          1          1           NaN
# 101                    4             6          2          2           NaN
# 103                    2            16          3          3           NaN
# 106                    6             8          6          4           NaN
# 200                    1             1          1          1           1.0
# 201                    4             5          3          3           4.0
# 202                    2            15          2          2           2.0
# 206                    6             7          4          3           7.0
# 1200                   1             1          1          1           1.0
# 1201                   4             5          3          3           4.0
# 1202                   2            15          2          2           2.0
# 1206                   6            10          4          4           7.0
#
#       patents   score  year
# 0           5  100.00  2012
# 1           1   91.67  2012
# 2          15   89.50  2012
# 9          16   78.55  2012
# 100         7  100.00  2013
# 101        11   93.94  2013
# 103         1   91.45  2013
# 106        19   85.07  2013
# 200         2  100.00  2014
# 201         6   99.09  2014
# 202         1   98.69  2014
# 206        28   92.84  2014
# 1200        3  100.00  2015
# 1201       10   98.66  2015
# 1202        1   97.54  2015
# 1206       29   92.25  2015

# %%
# 2 - Filtering pandas with logical_and
cwurData[np.logical_and(cwurData['quality_of_faculty']<20, cwurData['publications']<15 )]
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 7              8                        Yale University             USA
# 8              9                    Columbia University             USA
# 9             10     University of California, Berkeley             USA
# 19            20    University of California, San Diego             USA
# 100            1                     Harvard University             USA
# 101            2                    Stanford University             USA
# 102            3                   University of Oxford  United Kingdom
# 104            5                University of Cambridge  United Kingdom
# 105            6                    Columbia University             USA
# 106            7     University of California, Berkeley             USA
# 115           16  University of California, Los Angeles             USA
# 200            1                     Harvard University             USA
# 201            2                    Stanford University             USA
# 203            4                University of Cambridge  United Kingdom
# 204            5                   University of Oxford  United Kingdom
# 205            6                    Columbia University             USA
# 206            7     University of California, Berkeley             USA
# 214           15  University of California, Los Angeles             USA
# 218           19               Johns Hopkins University             USA
# 1200           1                     Harvard University             USA
# 1201           2                    Stanford University             USA
# 1203           4                University of Cambridge  United Kingdom
# 1204           5                   University of Oxford  United Kingdom
# 1205           6                    Columbia University             USA
# 1206           7     University of California, Berkeley             USA
# 1214          15  University of California, Los Angeles             USA
# 1215          16               Johns Hopkins University             USA
#
#       national_rank  quality_of_education  alumni_employment  \
# 0                 1                     7                  9
# 1                 2                     9                 17
# 2                 3                    17                 11
# 7                 6                    14                 31
# 8                 7                    23                 21
# 9                 8                    16                 52
# 19               14                    61                101
# 100               1                     1                  1
# 101               2                    11                  2
# 102               1                     7                 12
# 104               2                     3                 15
# 105               4                    13                  8
# 106               5                     6                 28
# 115              12                    38                 35
# 200               1                     1                  1
# 201               2                    11                  2
# 203               1                     2                 10
# 204               2                     7                 12
# 205               4                    13                  8
# 206               5                     4                 22
# 214              12                    27                 27
# 218              14                    24                 75
# 1200              1                     1                  1
# 1201              2                     9                  2
# 1203              1                     2                 10
# 1204              2                     7                 13
# 1205              4                    13                  6
# 1206              5                     5                 21
# 1214             12                    28                 27
# 1215             13                    18                 84
#
#       quality_of_faculty  publications  influence  citations  broad_impact  \
# 0                      1             1          1          1           NaN
# 1                      3            12          4          4           NaN
# 2                      5             4          2          2           NaN
# 7                     12            14          6         15           NaN
# 8                     10            13         12         14           NaN
# 9                      6             6          5          3           NaN
# 19                    15            10          8         10           NaN
# 100                    1             1          1          1           NaN
# 101                    4             6          2          2           NaN
# 102                   10            11          7         13           NaN
# 104                    5             9         11         10           NaN
# 105                    9            13          9         11           NaN
# 106                    6             8          6          4           NaN
# 115                   12             5         15          6           NaN
# 200                    1             1          1          1           1.0
# 201                    4             5          3          3           4.0
# 203                    5            10          9         12          13.0
# 204                   10            11         12         11          12.0
# 205                    9            14         13          9          13.0
# 206                    6             7          4          3           7.0
# 214                   12             6         14          7           6.0
# 218                   18             4         10          6           3.0
# 1200                   1             1          1          1           1.0
# 1201                   4             5          3          3           4.0
# 1203                   5            11          6         12          13.0
# 1204                  10             7         12          7           9.0
# 1205                   9            13         13         11          12.0
# 1206                   6            10          4          4           7.0
# 1214                  13             6         14          8           6.0
# 1215                  16             4         11          5           3.0
#
#       patents   score  year
# 0           5  100.00  2012
# 1           1   91.67  2012
# 2          15   89.50  2012
# 7          66   79.14  2012
# 8           5   78.86  2012
# 9          16   78.55  2012
# 19         22   63.11  2012
# 100         7  100.00  2013
# 101        11   93.94  2013
# 102        15   92.54  2013
# 104        39   90.24  2013
# 105        10   88.21  2013
# 106        19   85.07  2013
# 115        12   67.84  2013
# 200         2  100.00  2014
# 201         6   99.09  2014
# 203        48   97.64  2014
# 204        16   97.51  2014
# 205         4   97.41  2014
# 206        28   92.84  2014
# 214        10   78.35  2014
# 218         3   71.17  2014
# 1200        3  100.00  2015
# 1201       10   98.66  2015
# 1203       48   96.81  2015
# 1204       15   96.46  2015
# 1205        4   96.14  2015
# 1206       29   92.25  2015
# 1214        9   76.91  2015
# 1215        2   71.60  2015

# %%
# This is also same with previous code line. Therefore we can also use '&' for filtering.
shanghaiData[(shanghaiData['total_score']>70) & (shanghaiData['alumni']>50)]
# Out:
#      world_rank                              university_name national_rank  \
# 0             1                           Harvard University             1
# 1             2                      University of Cambridge             1
# 3             4           University of California, Berkeley             3
# 4             5  Massachusetts Institute of Technology (MIT)             4
# 500           1                           Harvard University             1
# 501           2                      University of Cambridge             1
# 503           4           University of California, Berkeley             3
# 1000          1                           Harvard University             1
# 1002          3           University of California, Berkeley             3
# 1003          4                      University of Cambridge             1
# 1510          1                           Harvard University             1
# 1512          3           University of California, Berkeley             3
# 1513          4                      University of Cambridge             1
# 2013          1                           Harvard University             1
# 2015          3           University of California, Berkeley             3
# 2016          4                      University of Cambridge             1
# 2514          1                           Harvard University             1
# 2515          2           University of California, Berkeley             2
# 2517          4  Massachusetts Institute of Technology (MIT)             4
# 3014          1                           Harvard University             1
# 3016          3  Massachusetts Institute of Technology (MIT)             3
# 3017          4           University of California, Berkeley             4
# 3514          1                           Harvard University             1
# 3516          3  Massachusetts Institute of Technology (MIT)             3
# 3517          4           University of California, Berkeley             4
# 3798          1                           Harvard University           1.0
# 3800          3           University of California, Berkeley           3.0
# 3801          4  Massachusetts Institute of Technology (MIT)           4.0
# 3897          1                           Harvard University             1
# 3899          3  Massachusetts Institute of Technology (MIT)             3
# 3900          4            University of California-Berkeley             4
# 4397          1                           Harvard University             1
# 4399          3  Massachusetts Institute of Technology (MIT)             3
#
#       total_score  alumni  award   hici     ns    pub   pcp  year
# 0           100.0   100.0  100.0  100.0  100.0  100.0  72.4  2005
# 1            73.6    99.8   93.4   53.3   56.6   70.9  66.9  2005
# 3            72.8    71.8   76.0   69.4   73.9   72.2  52.7  2005
# 4            70.1    74.0   80.6   66.7   65.8   64.3  53.0  2005
# 500         100.0   100.0  100.0  100.0  100.0  100.0  73.6  2006
# 501          72.6    96.3   91.5   53.8   59.5   67.1  66.5  2006
# 503          72.1    70.6   74.5   70.5   72.2   71.9  53.1  2006
# 1000        100.0   100.0  100.0  100.0  100.0  100.0  73.0  2007
# 1002         71.9    72.5   77.1   67.9   72.9   69.2  52.6  2007
# 1003         71.6    93.6   91.5   54.0   58.2   65.4  65.1  2007
# 1510        100.0   100.0  100.0  100.0  100.0  100.0  74.1  2008
# 1512         71.4    69.0   77.1   68.8   70.6   70.0  53.0  2008
# 1513         70.4    90.3   91.5   53.6   56.0   64.1  65.0  2008
# 2013        100.0   100.0  100.0  100.0  100.0  100.0  74.8  2009
# 2015         71.0    67.4   77.1   68.4   71.1   69.0  53.2  2009
# 2016         70.2    89.4   91.5   53.8   53.9   65.4  65.5  2009
# 2514        100.0   100.0  100.0  100.0  100.0  100.0  69.2  2010
# 2515         72.4    67.6   79.3   69.0   70.9   70.6  54.2  2010
# 2517         71.4    70.5   80.3   66.8   70.1   61.4  64.5  2010
# 3014        100.0   100.0  100.0  100.0  100.0  100.0  70.5  2011
# 3016         72.0    72.8   81.9   67.9   70.6   60.6  63.7  2011
# 3017         71.9    68.3   79.3   70.0   69.5   69.4  53.1  2011
# 3514        100.0   100.0  100.0  100.0  100.0  100.0  71.1  2012
# 3516         71.8    69.0   83.2   68.2   69.2   61.6  64.1  2012
# 3517         71.6    67.5   80.9   69.7   68.5   68.1  53.4  2012
# 3798        100.0   100.0  100.0  100.0  100.0  100.0  72.5  2013
# 3800         71.3    67.8   79.0   69.7   68.5   68.1  54.7  2013
# 3801         71.1    68.0   81.3   68.2   69.7   60.1  65.0  2013
# 3897        100.0   100.0  100.0  100.0  100.0  100.0  75.3  2014
# 3899         70.5    68.4   80.7   60.6   73.6   61.5  67.1  2014
# 3900         70.1    66.8   79.4   65.3   67.5   68.1  55.9  2014
# 4397        100.0   100.0  100.0  100.0  100.0  100.0  76.6  2015
# 4399         70.4    68.2   80.7   60.6   73.1   61.1  68.0  2015

# %% [markdown]
# LIST COMPREHENSİON

# %%
threshold = sum(timesData.teaching) / len(timesData.teaching)
timesData["ratio"] = ["high" if i > threshold else "low" for i in timesData.teaching]
timesData.loc[:10,["ratio","teaching"]]
# Out:
#    ratio  teaching
# 0   high      99.7
# 1   high      97.7
# 2   high      97.8
# 3   high      98.3
# 4   high      90.9
# 5   high      90.5
# 6   high      88.2
# 7   high      84.2
# 8   high      89.2
# 9   high      92.1
# 10  high      83.0

# %% [markdown]
# MISSING DATA

# %%
cwurData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   world_rank            2200 non-null   int64
#  1   institution           2200 non-null   object
#  2   country               2200 non-null   object
#  3   national_rank         2200 non-null   int64
#  4   quality_of_education  2200 non-null   int64
#  5   alumni_employment     2200 non-null   int64
#  6   quality_of_faculty    2200 non-null   int64
#  7   publications          2200 non-null   int64
#  8   influence             2200 non-null   int64
#  9   citations             2200 non-null   int64
#  10  broad_impact          2000 non-null   float64
#  11  patents               2200 non-null   int64
#  12  score                 2200 non-null   float64
#  13  year                  2200 non-null   int64
# dtypes: float64(2), int64(10), object(2)
# memory usage: 240.8+ KB

# %%
# Lets check broad_impact
cwurData["broad_impact"].value_counts(dropna =False)
# Out:
# broad_impact
# NaN      200
# 642.0     21
# 849.0     20
# 800.0     19
# 783.0     17
#         ...
# 88.0       1
# 100.0      1
# 30.0       1
# 45.0       1
# 11.0       1
# Name: count, Length: 344, dtype: int64

# %%
# Lets drop nan values
cwurData["broad_impact"].dropna(inplace = True)  
cwurData["broad_impact"].value_counts(dropna =False)
# Out:
# broad_impact
# NaN      200
# 642.0     21
# 849.0     20
# 800.0     19
# 783.0     17
#         ...
# 88.0       1
# 100.0      1
# 30.0       1
# 45.0       1
# 11.0       1
# Name: count, Length: 344, dtype: int64

# %% [markdown]
# Outlier Detection

# %%
def detect_outliers(df,features):
    outlier_indices = []
    
    for c in features:
        Q1 = np.percentile(df[c],25)
        Q3 = np.percentile(df[c],75)
        IQR = Q3 - Q1
        outlier_step = IQR * 1.5
        outlier_list_col = df[(df[c] < Q1 - outlier_step) | (df[c] > Q3 + outlier_step)].index
        outlier_indices.extend(outlier_list_col)
    
    outlier_indices = Counter(outlier_indices)
    multiple_outliers = list(i for i, v in outlier_indices.items() if v > 2)
    
    return multiple_outliers

# %%
timesData.loc[detect_outliers(timesData,["research","teaching","citations"])]
# Out:
# Empty DataFrame
# Columns: [world_rank, university_name, country, teaching, international, research, citations, income, total_score, num_students, student_staff_ratio, international_students, female_male_ratio, year, ratio]
# Index: []

# %%
timesData.boxplot(column="research",by = "year")
plt.show()
