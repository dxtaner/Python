# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

import os
for dirname, _, filenames in os.walk('input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# input\combats.csv
# input\cwurData.csv
# input\educational_attainment_supplementary_data.csv
# input\education_expenditure_supplementary_data.csv
# input\Iris.csv
# input\kl.csv
# input\master.csv
# input\pokemon.csv
# input\school_and_country_table.csv
# input\shanghaiData.csv
# input\tests.csv
# input\timesData.csv

# %%
data = pd.read_csv('input/suicide-rates-overview-1985-to-2016/master.csv')
data.head()  # see first 5 rows
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %% [markdown]
# Examples Team Data

# %%
team = ["Fenerbahce", "Galatasaray"]
team_value = ["185M", "190M"]
list_label = ["team", "team_value"]
list_col = [team, team_value]

# %%
zipped = list(zip(list_label, list_col))
data_dict = dict(zipped)

# %%
df = pd.DataFrame(data_dict)
print(df)
# Out:
#           team team_value
# 0   Fenerbahce       185M
# 1  Galatasaray       190M

# %%
df["Player_Number"] = ["25", "23"]
df["Expenses"] = 100000000  
print(df)
# Out:
#           team team_value Player_Number   Expenses
# 0   Fenerbahce       185M            25  100000000
# 1  Galatasaray       190M            23  100000000

# %% [markdown]
# Suicede Data

# %%
import numpy as np

np.random.seed(0)
data = pd.DataFrame({
    'suicides_no': np.random.randint(0, 500, size=100),
    'population': np.random.randint(1, 1000, size=100)
})

# %%
data1 = data.loc[:, ["suicides_no", "population"]]
data1.plot()
plt.show()

# %%
data1.plot(subplots=True)
plt.show()

# %%
data1.plot(kind="scatter", x="population", y="suicides_no")
plt.show()

# %%
data1.plot(kind="hist", y="suicides_no", range=(0, 500), bins=10)
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=1)
data1.plot(kind="hist", y="suicides_no", bins=50, range=(0, 500), ax=axes[0])
data1.plot(kind="hist", y="suicides_no", bins=50, range=(0, 500), ax=axes[1], cumulative=True)
plt.savefig('graph.png')
plt.show()

# %% [markdown]
# STATISTICAL EXPLORATORY DATA ANALYSIS

# %%
data.describe()
# Out:
#        suicides_no  population
# count   100.000000  100.000000
# mean    241.530000  480.570000
# std     142.656432  305.822925
# min       9.000000   12.000000
# 25%     116.500000  194.750000
# 50%     243.500000  469.000000
# 75%     371.500000  771.000000
# max     488.000000  974.000000

# %%
time_list = ["1985-01-01","2016-12-31"]
print(type(time_list[1])) #
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
# Örnek zaman serisi verisi oluşturma
dates = pd.date_range(start='1/1/1987', periods=100, freq='M')
data2 = pd.DataFrame({
    'date': dates,
    'suicides_no': np.random.randint(0, 500, size=100),
    'population': np.random.randint(1, 1000, size=100)
})
data2.set_index('date', inplace=True)

# %%
data2.resample("A").mean()
# Out:
#             suicides_no  population
# date
# 1987-12-31   279.500000  470.666667
# 1988-12-31   313.750000  742.083333
# 1989-12-31   231.166667  389.583333
# 1990-12-31   279.250000  440.666667
# 1991-12-31   192.416667  374.166667
# 1992-12-31   233.833333  428.333333
# 1993-12-31   238.250000  495.916667
# 1994-12-31   224.750000  573.750000
# 1995-12-31   215.500000  355.500000

# %% [markdown]
# RESAMPLING PANDAS TIME SERIES

# %%
data2.resample("M").mean()
# Out:
#             suicides_no  population
# date
# 1987-01-31        363.0       822.0
# 1987-02-28        269.0       308.0
# 1987-03-31        368.0       175.0
# 1987-04-30        296.0       149.0
# 1987-05-31        328.0       950.0
# ...                 ...         ...
# 1994-12-31        258.0        44.0
# 1995-01-31         27.0        84.0
# 1995-02-28        467.0       434.0
# 1995-03-31        217.0       810.0
# 1995-04-30        151.0        94.0
#
# [100 rows x 2 columns]

# %%
data2.resample("M").mean()
# Out:
#             suicides_no  population
# date
# 1987-01-31        363.0       822.0
# 1987-02-28        269.0       308.0
# 1987-03-31        368.0       175.0
# 1987-04-30        296.0       149.0
# 1987-05-31        328.0       950.0
# ...                 ...         ...
# 1994-12-31        258.0        44.0
# 1995-01-31         27.0        84.0
# 1995-02-28        467.0       434.0
# 1995-03-31        217.0       810.0
# 1995-04-30        151.0        94.0
#
# [100 rows x 2 columns]

# %%
data2.resample("M").first().interpolate("linear")
# Out:
#             suicides_no  population
# date
# 1987-01-31          363         822
# 1987-02-28          269         308
# 1987-03-31          368         175
# 1987-04-30          296         149
# 1987-05-31          328         950
# ...                 ...         ...
# 1994-12-31          258          44
# 1995-01-31           27          84
# 1995-02-28          467         434
# 1995-03-31          217         810
# 1995-04-30          151          94
#
# [100 rows x 2 columns]

# %%
data2.resample("M").mean().interpolate("linear")
# Out:
#             suicides_no  population
# date
# 1987-01-31        363.0       822.0
# 1987-02-28        269.0       308.0
# 1987-03-31        368.0       175.0
# 1987-04-30        296.0       149.0
# 1987-05-31        328.0       950.0
# ...                 ...         ...
# 1994-12-31        258.0        44.0
# 1995-01-31         27.0        84.0
# 1995-02-28        467.0       434.0
# 1995-03-31        217.0       810.0
# 1995-04-30        151.0        94.0
#
# [100 rows x 2 columns]

# %%
# Veri okuma
data = pd.read_csv('input/suicide-rates-overview-1985-to-2016/master.csv')
data = data.set_index("year")
data.head()
# Out:
#       country     sex          age  suicides_no  population  \
# year
# 1987  Albania    male  15-24 years           21      312900
# 1987  Albania    male  35-54 years           16      308000
# 1987  Albania  female  15-24 years           14      289700
# 1987  Albania    male    75+ years            1       21800
# 1987  Albania    male  25-34 years            9      274300
#
#       suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# year
# 1987               6.71  Albania1987           NaN      2,156,624,900
# 1987               5.19  Albania1987           NaN      2,156,624,900
# 1987               4.83  Albania1987           NaN      2,156,624,900
# 1987               4.59  Albania1987           NaN      2,156,624,900
# 1987               3.28  Albania1987           NaN      2,156,624,900
#
#       gdp_per_capita ($)       generation
# year
# 1987                 796     Generation X
# 1987                 796           Silent
# 1987                 796     Generation X
# 1987                 796  G.I. Generation
# 1987                 796          Boomers

# %%
data["sex"][1987]
# Out:
# year
# 1987      male
# 1987      male
# 1987    female
# 1987      male
# 1987      male
#          ...
# 1987    female
# 1987    female
# 1987    female
# 1987    female
# 1987      male
# Name: sex, Length: 648, dtype: object

# %%
data.sex[1987]
# Out:
# year
# 1987      male
# 1987      male
# 1987    female
# 1987      male
# 1987      male
#          ...
# 1987    female
# 1987    female
# 1987    female
# 1987    female
# 1987      male
# Name: sex, Length: 648, dtype: object

# %%
data.loc[1987, ["sex"]]
# Out:
#          sex
# year
# 1987    male
# 1987    male
# 1987  female
# 1987    male
# 1987    male
# ...      ...
# 1987  female
# 1987  female
# 1987  female
# 1987  female
# 1987    male
#
# [648 rows x 1 columns]

# %%
data[["sex", "age"]]
# Out:
#          sex          age
# year
# 1987    male  15-24 years
# 1987    male  35-54 years
# 1987  female  15-24 years
# 1987    male    75+ years
# 1987    male  25-34 years
# ...      ...          ...
# 2014  female  35-54 years
# 2014  female    75+ years
# 2014    male   5-14 years
# 2014  female   5-14 years
# 2014  female  55-74 years
#
# [27820 rows x 2 columns]

# %%
# Seriler ve data frame'ler arasında seçim yapmak
print(type(data["sex"]))     # Seriler
print(type(data[["sex"]]))   # Data frame'ler

# Serileri dilimleme ve indeksleme
data.loc[:, "sex":"suicides_no"]
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
#          sex          age  suicides_no
# year
# 1987    male  15-24 years           21
# 1987    male  35-54 years           16
# 1987  female  15-24 years           14
# 1987    male    75+ years            1
# 1987    male  25-34 years            9
# ...      ...          ...          ...
# 2014  female  35-54 years          107
# 2014  female    75+ years            9
# 2014    male   5-14 years           60
# 2014  female   5-14 years           44
# 2014  female  55-74 years           21
#
# [27820 rows x 3 columns]

# %%
data.loc[::-1, "sex":"suicides_no"]
# Out:
#          sex          age  suicides_no
# year
# 2014  female  55-74 years           21
# 2014  female   5-14 years           44
# 2014    male   5-14 years           60
# 2014  female    75+ years            9
# 2014  female  35-54 years          107
# ...      ...          ...          ...
# 1987    male  25-34 years            9
# 1987    male    75+ years            1
# 1987  female  15-24 years           14
# 1987    male  35-54 years           16
# 1987    male  15-24 years           21
#
# [27820 rows x 3 columns]

# %% [markdown]
# FILTERING DATA FRAMES

# %%
boolean = data.suicides_no > 100
data[boolean]
# Out:
#          country     sex          age  suicides_no  population  \
# year
# 1985   Argentina    male    75+ years          202      363000
# 1985   Argentina    male  55-74 years          485     1997000
# 1985   Argentina    male  35-54 years          414     3346300
# 1985   Argentina  female  55-74 years          210     2304000
# 1985   Argentina    male  25-34 years          177     2234200
# ...          ...     ...          ...          ...         ...
# 2014  Uzbekistan  female  15-24 years          347     2992817
# 2014  Uzbekistan    male  55-74 years          144     1271111
# 2014  Uzbekistan    male  15-24 years          347     3126905
# 2014  Uzbekistan  female  25-34 years          162     2735238
# 2014  Uzbekistan  female  35-54 years          107     3620833
#
#       suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# year
# 1985              55.65   Argentina1985         0.694     88,416,668,900
# 1985              24.29   Argentina1985         0.694     88,416,668,900
# 1985              12.37   Argentina1985         0.694     88,416,668,900
# 1985               9.11   Argentina1985         0.694     88,416,668,900
# 1985               7.92   Argentina1985         0.694     88,416,668,900
# ...                 ...             ...           ...                ...
# 2014              11.59  Uzbekistan2014         0.675     63,067,077,179
# 2014              11.33  Uzbekistan2014         0.675     63,067,077,179
# 2014              11.10  Uzbekistan2014         0.675     63,067,077,179
# 2014               5.92  Uzbekistan2014         0.675     63,067,077,179
# 2014               2.96  Uzbekistan2014         0.675     63,067,077,179
#
#       gdp_per_capita ($)       generation
# year
# 1985                3264  G.I. Generation
# 1985                3264  G.I. Generation
# 1985                3264           Silent
# 1985                3264  G.I. Generation
# 1985                3264          Boomers
# ...                  ...              ...
# 2014                2309       Millenials
# 2014                2309          Boomers
# 2014                2309       Millenials
# 2014                2309       Millenials
# 2014                2309     Generation X
#
# [8063 rows x 11 columns]

# %%
first_filter = data.suicides_no > 200
second_filter = data.population > 1000000
data[first_filter & second_filter]
# Out:
#          country     sex          age  suicides_no  population  \
# year
# 1985   Argentina    male  55-74 years          485     1997000
# 1985   Argentina    male  35-54 years          414     3346300
# 1985   Argentina  female  55-74 years          210     2304000
# 1986   Argentina    male  55-74 years          530     2008300
# 1986   Argentina    male  35-54 years          478     3365200
# ...          ...     ...          ...          ...         ...
# 2013  Uzbekistan    male  15-24 years          320     3171202
# 2014  Uzbekistan    male  35-54 years          519     3421300
# 2014  Uzbekistan    male  25-34 years          318     2739150
# 2014  Uzbekistan  female  15-24 years          347     2992817
# 2014  Uzbekistan    male  15-24 years          347     3126905
#
#       suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# year
# 1985              24.29   Argentina1985         0.694     88,416,668,900
# 1985              12.37   Argentina1985         0.694     88,416,668,900
# 1985               9.11   Argentina1985         0.694     88,416,668,900
# 1986              26.39   Argentina1986           NaN    110,934,442,763
# 1986              14.20   Argentina1986           NaN    110,934,442,763
# ...                 ...             ...           ...                ...
# 2013              10.09  Uzbekistan2013         0.672     57,690,453,461
# 2014              15.17  Uzbekistan2014         0.675     63,067,077,179
# 2014              11.61  Uzbekistan2014         0.675     63,067,077,179
# 2014              11.59  Uzbekistan2014         0.675     63,067,077,179
# 2014              11.10  Uzbekistan2014         0.675     63,067,077,179
#
#       gdp_per_capita ($)       generation
# year
# 1985                3264  G.I. Generation
# 1985                3264           Silent
# 1985                3264  G.I. Generation
# 1986                4072  G.I. Generation
# 1986                4072           Silent
# ...                  ...              ...
# 2013                2150       Millenials
# 2014                2309     Generation X
# 2014                2309       Millenials
# 2014                2309       Millenials
# 2014                2309       Millenials
#
# [4649 rows x 11 columns]

# %% [markdown]
# TRANSFORMING DATA

# %%
def div(n):
    return n/2
data.suicides_no.apply(div)
# Out:
# year
# 1987    10.5
# 1987     8.0
# 1987     7.0
# 1987     0.5
# 1987     4.5
#         ...
# 2014    53.5
# 2014     4.5
# 2014    30.0
# 2014    22.0
# 2014    10.5
# Name: suicides_no, Length: 27820, dtype: float64

# %%
data.suicides_no.apply(lambda n : n/2)
# Out:
# year
# 1987    10.5
# 1987     8.0
# 1987     7.0
# 1987     0.5
# 1987     4.5
#         ...
# 2014    53.5
# 2014     4.5
# 2014    30.0
# 2014    22.0
# 2014    10.5
# Name: suicides_no, Length: 27820, dtype: float64

# %%
# Defining column using other columns
data["Ratio"] = data.population / data.suicides_no
data.head()
# Out:
#       country     sex          age  suicides_no  population  \
# year
# 1987  Albania    male  15-24 years           21      312900
# 1987  Albania    male  35-54 years           16      308000
# 1987  Albania  female  15-24 years           14      289700
# 1987  Albania    male    75+ years            1       21800
# 1987  Albania    male  25-34 years            9      274300
#
#       suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# year
# 1987               6.71  Albania1987           NaN      2,156,624,900
# 1987               5.19  Albania1987           NaN      2,156,624,900
# 1987               4.83  Albania1987           NaN      2,156,624,900
# 1987               4.59  Albania1987           NaN      2,156,624,900
# 1987               3.28  Albania1987           NaN      2,156,624,900
#
#       gdp_per_capita ($)       generation         Ratio
# year
# 1987                 796     Generation X  14900.000000
# 1987                 796           Silent  19250.000000
# 1987                 796     Generation X  20692.857143
# 1987                 796  G.I. Generation  21800.000000
# 1987                 796          Boomers  30477.777778

# %%
print(data.index.name)
data.index.name = "index_name"
data.head()
# Out:
# year
#             country     sex          age  suicides_no  population  \
# index_name
# 1987        Albania    male  15-24 years           21      312900
# 1987        Albania    male  35-54 years           16      308000
# 1987        Albania  female  15-24 years           14      289700
# 1987        Albania    male    75+ years            1       21800
# 1987        Albania    male  25-34 years            9      274300
#
#             suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# index_name
# 1987                     6.71  Albania1987           NaN      2,156,624,900
# 1987                     5.19  Albania1987           NaN      2,156,624,900
# 1987                     4.83  Albania1987           NaN      2,156,624,900
# 1987                     4.59  Albania1987           NaN      2,156,624,900
# 1987                     3.28  Albania1987           NaN      2,156,624,900
#
#             gdp_per_capita ($)       generation         Ratio
# index_name
# 1987                       796     Generation X  14900.000000
# 1987                       796           Silent  19250.000000
# 1987                       796     Generation X  20692.857143
# 1987                       796  G.I. Generation  21800.000000
# 1987                       796          Boomers  30477.777778

# %% [markdown]
# HIERARCHICAL INDEXING

# %%
data = pd.read_csv('input/suicide-rates-overview-1985-to-2016/master.csv')
data.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# 3                 796  G.I. Generation
# 4                 796          Boomers

# %%
data1 = data.set_index(["country","sex"]) 
data1.head(100)
# Out:
#                 year          age  suicides_no  population  suicides/100k pop  \
# country sex
# Albania male    1987  15-24 years           21      312900               6.71
#         male    1987  35-54 years           16      308000               5.19
#         female  1987  15-24 years           14      289700               4.83
#         male    1987    75+ years            1       21800               4.59
#         male    1987  25-34 years            9      274300               3.28
# ...              ...          ...          ...         ...                ...
#         female  1996   5-14 years            1      354100               0.28
#         male    1997  25-34 years           36      236000              15.25
#         male    1997  15-24 years           33      244400              13.50
#         male    1997    75+ years            3       25400              11.81
#         male    1997  35-54 years           30      380800               7.88
#
#                country-year  HDI for year  gdp_for_year ($)   \
# country sex
# Albania male    Albania1987           NaN      2,156,624,900
#         male    Albania1987           NaN      2,156,624,900
#         female  Albania1987           NaN      2,156,624,900
#         male    Albania1987           NaN      2,156,624,900
#         male    Albania1987           NaN      2,156,624,900
# ...                     ...           ...                ...
#         female  Albania1996           NaN      3,314,898,292
#         male    Albania1997           NaN      2,359,903,108
#         male    Albania1997           NaN      2,359,903,108
#         male    Albania1997           NaN      2,359,903,108
#         male    Albania1997           NaN      2,359,903,108
#
#                 gdp_per_capita ($)       generation
# country sex
# Albania male                   796     Generation X
#         male                   796           Silent
#         female                 796     Generation X
#         male                   796  G.I. Generation
#         male                   796          Boomers
# ...                            ...              ...
#         female                1127       Millenials
#         male                   793     Generation X
#         male                   793     Generation X
#         male                   793  G.I. Generation
#         male                   793          Boomers
#
# [100 rows x 10 columns]
